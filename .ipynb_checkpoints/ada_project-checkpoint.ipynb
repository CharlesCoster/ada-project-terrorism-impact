# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlesCoster/ada-project-terrorism-impact/blob/master/ada_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tout acte terroriste constitue pour nos sociétés démocratiques une véritable agression psychologique et émotionnelle, capable d’engendrer de profondes blessures au sein de la population. D’un point de vue sémantique, le terrorisme atteint ici son but ultime, en instaurant un **climat d’insécurité, de crainte et de terreur**. L’acte lui-même, autant que la menace d’un attentat terroriste, si imprécise soit-elle, suffit à **influencer profondément nos activités professionnelles, nos loisirs et nos déplacements**. Le caractère profondément intrusif et violent du terrorisme peut favoriser dès lors l’apparition de troubles psychiatriques ou de comportements à risque. Le médecin de premier recours est appelé à jouer ici un rôle clé, tant dans le dépistage de réactions pathologiques, que dans l’accompagnement des patients et dans le soutien de la population générale.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Loads the two political & economic datasets. These datasets contains the following items (for more details, see the [Codebook](http://www.cpds-data.org/images/Update2019/Codebook-CPDS-1960-2017-Update-2019.pdf?fbclid=IwAR2pUv2Lr_G24RqwSwkTeQTLWfZiwznPPuDI8fLLniJKuCjOuhyzHcHDYtU)):
#
#
# 1.   General informations : year, country, european country, ...
# 2.   Governements : composition, cabinet composition, news since last governement, relative power positions, ...
# 3.   Elections : share of votes and seats in parliament, voter turnout, ...
# 4.   Party system :
# 5.   Institutions :
# 6.   Openness of the economy :
# 7.   Macroeconomy data :
# 8.   Labour force data :
# 9.   Industrial disputes and trade unions :
# 10.  Public social expenditure and revenue data :
# 11.  Educational expenditure and attainment data :
# 12.  Family policiy :
# 13.  Larbour market policy :
# 14.  Income inequality :
# 15.  Demography :

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 921kB 1.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.1MB 14.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 11.8MB 26.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.5MB 56.3MB/s eta 0:00:01
# ...

# %%
cpds = pd.read_excel('http://www.cpds-data.org/images/Update2019/CPDS-1960-2017-Update-2019.xlsx', parse_dates=True)

# %%
gov_comp = pd.read_excel('http://www.cpds-data.org/images/Update2019/Government-Composition-1960-2017-Update-2019.xlsx', parse_dates=True)

# %%
cpds.head()
# Out:
#    year    country  countryn  iso  ...       pop65   elderly  year_13  country_13
# 0  1960  Australia         1  AUS  ...  871.096008  8.465703     1960   Australia
# 1  1961  Australia         1  AUS  ...  890.710999  8.488172     1961   Australia
# 2  1962  Australia         1  AUS  ...  909.627991  8.507805     1962   Australia
# 3  1963  Australia         1  AUS  ...  928.943970  8.526904     1963   Australia
# 4  1964  Australia         1  AUS  ...  943.978027  8.492668     1964   Australia
#
# [5 rows x 319 columns]

# %% [markdown]
# Construct a reduce dataset with 3 countries of interest for now

# %%
cpds_red = cpds[cpds.country.isin(['France','Germany','United Kingdom'])]

# %% [markdown]
# Plot real GDP for these countries from 1960 to 2017

# %%
cpds_red.set_index('year').groupby('country')['realgdpgr'].plot(legend=True)
# Out:
# country
# France            AxesSubplot(0.125,0.125;0.775x0.755)
# Germany           AxesSubplot(0.125,0.125;0.775x0.755)
# United Kingdom    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: realgdpgr, dtype: object

# %% [markdown]
# Plot the polulations for these 3 countries

# %%
cpds_red.set_index('year').groupby('country')['pop'].plot(legend=True)
# Out:
# country
# France            AxesSubplot(0.125,0.125;0.775x0.755)
# Germany           AxesSubplot(0.125,0.125;0.775x0.755)
# United Kingdom    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: pop, dtype: object

# %%
for c in ['France', 'United Kingdom', 'Germany'] :
  df = cpds_red[cpds_red.country.isin([c])]
  df.set_index('year').groupby('country')['gov_right1','gov_cent1','gov_left1'].plot(legend=True,title=c)
plt.show()

# %%
for c in ['France', 'United Kingdom', 'Germany'] :
  df = cpds_red[cpds_red.country.isin([c])]
  df.set_index('year').groupby('country')['gov_right2','gov_cent2','gov_left2'].plot(legend=True,title=c)
plt.show()

# %%
for c in ['France', 'United Kingdom', 'Germany'] :
  df = cpds_red[cpds_red.country.isin([c])]
  df.set_index('year').groupby('country')['gov_right3','gov_cent3','gov_left3'].plot(legend=True,title=c)
plt.show()

# %%
for c in ['France', 'United Kingdom', 'Germany'] :
  df = cpds_red[cpds_red.country.isin([c])]
  print(df.columns[df.columns.str.contains('social' or 'left')])
  #df.set_index('year').groupby('country')['gov_right3','gov_cent3','gov_left3'].plot(legend=True,title=c)
plt.show()
# Out:
# Index(['social1', 'social2', 'social3', 'social4', 'social5', 'social6',
#        'social7', 'social8', 'ssocial1', 'ssocial2', 'ssocial3', 'ssocial4',
#        'ssocial5', 'ssocial6', 'ssocial7', 'ssocial8'],
#       dtype='object')
# Index(['social1', 'social2', 'social3', 'social4', 'social5', 'social6',
#        'social7', 'social8', 'ssocial1', 'ssocial2', 'ssocial3', 'ssocial4',
#        'ssocial5', 'ssocial6', 'ssocial7', 'ssocial8'],
#       dtype='object')
# Index(['social1', 'social2', 'social3', 'social4', 'social5', 'social6',
#        'social7', 'social8', 'ssocial1', 'ssocial2', 'ssocial3', 'ssocial4',
#        'ssocial5', 'ssocial6', 'ssocial7', 'ssocial8'],
#       dtype='object')

# %% [markdown]
# Plot the cabinet composition according to the Schmidt index :
# 1. hegemony of right-wing (and centre) par-ties
# 2. dominance    of    right-wing    (and centre)    parties
# 3. balance    of    powerbetween    left    andright
# 4. dominance of social-democratic and other left parties
# 5. hegemony of social-democratic and other left parties

# %%
cpds_red.set_index('year').groupby('country')['gov_party'].plot(legend=True)
plt.show()

# %% [markdown]
# It should be interesting to work with [vote intentions](https://www.politico.eu/europe-poll-of-polls/france/). The code to retrieve datas from scatter plot is write on an other file. Ask to get it... Here is an example of such a plot

# %%
from IPython.display import Image
Image(filename='germany-poll.png')

# %%
df = cpds[cpds.country.isin(['France'])]

# %% [markdown]
# TODO
#
#
# *   GDP across years
# *   Population
# *   Happyness index
# *   Political elections

# %%
df.head()
# Out:
#      year country  countryn  iso  ...        pop65    elderly  year_13  country_13
# 490  1960  France        12  FRA  ...  5386.888184  11.549932     1960      France
# 491  1961  France        12  FRA  ...  5478.551758  11.621629     1961      France
# 492  1962  France        12  FRA  ...  5616.622070  11.701540     1962      France
# 493  1963  France        12  FRA  ...  5737.923828  11.748411     1963      France
# 494  1964  France        12  FRA  ...  5852.942871  11.858385     1964      France
#
# [5 rows x 319 columns]

# %%
df.set_index('year').vturn.plot()
plt.show()

# %%
df['social'] = df['social1']+df['social2']+df['social3']+df['social4']+df['social5']+df['social6']+df['social7']+df['social8']
df['leftsoc'] = df['leftsoc1']+df['leftsoc2']+df['leftsoc3']+df['leftsoc4']+df['leftsoc5']
df['comm'] = df['comm1']+df['comm2']+df['comm3']+df['comm4']
df['agrarian'] = df['agrarian1']+df['agrarian2']+df['agrarian3']
df['conserv'] = df['conserv1']+df['conserv2']+df['conserv3']+df['conserv4']+df['conserv5']+df['conserv6']+df['conserv7']+df['conserv8']
df['relig'] = df['relig1']+df['relig2']+df['relig3']+df['relig4']+df['relig5']+df['relig6']+df['relig7']
df['liberal'] = df['liberal1']+df['liberal2']+df['liberal3']+df['liberal4']+df['liberal5']+df['liberal6']+df['liberal7']+df['liberal8']+df['liberal9']
df['protest'] = df['protest1']+df['protest2']+df['protest3']+df['protest4']+df['protest5']
df['green'] = df['green1']+df['green2']+df['green3']
df['ethnic'] = df['ethnic1']+df['ethnic2']+df['ethnic3']+df['ethnic4']
df['right'] = df['right1']+df['right2']+df['right3']+df['right4']+df['right5']+df['right6']
df['allia'] = df['allia1']+df['allia2']+df['allia3']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
political_part = ['leftsoc','comm','right','social','conserv']

# %%
df.set_index('year')[political_part].plot()
plt.show()

# %%
# !pip install PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# # Tourism

# %%
import pandas as pd

df_tourism = pd.read_csv('tourism.csv',sep='\t')

# %%
df_tourism = df_tourism[df_tourism.VAR.isin(['EXPORT_TOTAL','IMPORT_TOTAL'])&df_tourism.CUR.isin(['NAT'])]
df_tourism['Growth'] = df_tourism.groupby(['COUNTRY','VAR']).Value.pct_change()
df_tourism = df_tourism[['COUNTRY','VAR','YEAR','Growth']]
df_tourism.columns=['country_code','tourism_var','year','tourism_growth']
df_tourism.head()
# Out:
#   country_code   tourism_var  year  tourism_growth
# 0          AUS  EXPORT_TOTAL  2008             NaN
# 1          AUS  EXPORT_TOTAL  2009        0.034807
# 2          AUS  EXPORT_TOTAL  2010       -0.002731
# 3          AUS  EXPORT_TOTAL  2011       -0.021077
# 4          AUS  EXPORT_TOTAL  2012       -0.021957

# %%
df_tourism.set_index(['country_code','year'],inplace=True)
df_tourism = df_tourism.pivot_table(index=df_tourism.index,columns='tourism_var',values='tourism_growth')
df_tourism.reset_index(inplace=True)
df_tourism.head()
# Out:
# tourism_var        index  EXPORT_TOTAL  IMPORT_TOTAL
# 0            (AUS, 2009)      0.034807     -0.002004
# 1            (AUS, 2010)     -0.002731      0.058791
# 2            (AUS, 2011)     -0.021077      0.097287
# 3            (AUS, 2012)     -0.021957      0.053171
# 4            (AUS, 2013)      0.043211      0.093014

# %%
df_tourism.columns=['country_year','gde','gdi']
df_tourism['country_code'] = df_tourism.country_year.apply(lambda x:x[0])
df_tourism['year'] = df_tourism.country_year.apply(lambda x:x[1])
df_tourism.drop('country_year',axis=1,inplace=True)
df_tourism.head()
# Out:
#         gde       gdi country_code  year
# 0  0.034807 -0.002004          AUS  2009
# 1 -0.002731  0.058791          AUS  2010
# 2 -0.021077  0.097287          AUS  2011
# 3 -0.021957  0.053171          AUS  2012
# 4  0.043211  0.093014          AUS  2013

# %% [markdown]
# # Terrorism

# %%
# We import dblp from google drive
id='1bfZzGpT5jQwYuLHfdgPO_4JSLyPsIVBR'

downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('globalterrorismdb_0919dist.xlsx')  
dblp = pd.read_excel('globalterrorismdb_0919dist.xlsx',index_col='eventid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-804a1ad52ef5> in <module>
#       3
#       4
# ----> 5 downloaded = drive.CreateFile({'id':id})
#       6 downloaded.GetContentFile('globalterrorismdb_0919dist.xlsx')
#       7 dblp = pd.read_excel('globalterrorismdb_0919dist.xlsx',index_col='eventid')
#
# NameError: name 'drive' is not defined

# %%
dblp.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7043dbbf00ca> in <module>
# ----> 1 dblp.head()
#
# NameError: name 'dblp' is not defined

# %%
# Keep only datas with political social economical or social goal, with intention to coerce,... and outsie international humanitarian law
terr_df = dblp[dblp.crit1.isin([1])&dblp.crit2.isin([1])&dblp.crit3.isin([1])]

# Keep variabls of interest
features_col = ['iyear','imonth','iday','country_txt','city','attacktype1_txt','attacktype2_txt','attacktype3_txt',
                'targtype1_txt','targtype2_txt','weaptype1_txt','weaptype2_txt','weaptype3_txt','weaptype4_txt','gname',
                'nkill','nkillter']
              
terr_df = terr_df[features_col].head()

# %%
terr_df_year = terr_df.groupby('iyear')['nkill'].sum()
plt.plot(terr_df_year.index, terr_df_year)
plt.xlabel('years')
plt.ylabel('number of death due to terrorism')
plt.show()

# %%
terr_df_att= terr_df['iyear'].value_counts()

plt.figure(figsize=(10,5))
terr_df_att.sort_index().plot()
plt.plot(terr_df_year.index, terr_df_year)
plt.legend(['number of attacks','number of killed'])
plt.xlabel('years')
plt.show()

# %%
terr_df['nkill'].describe()

# %% [markdown]
# ### Lets study the number of attack with more than 12 killed in one attack

# %%
terr_impact = terr_df[terr_df['nkill'] > 12]
terr_impact['iyear'].value_counts().sort_index().plot(kind='bar')
plt.legend(['impact attack', 'total attack'])
plt.show()

# %% [markdown]
# # 1. Terrorism evolution

# %%
# Weapon occurence per year

# %%
# Attack type occurence per year

# %%
# Terrorist groups occurence per year

# %% [markdown]
# #4. Correlations

# %%
df_terrorism = dblp.groupby(['iyear','country_txt']).size().to_frame().reset_index()
df_new = dblp.groupby(['iyear','country_txt']).nkill.sum().to_frame().reset_index()
df_terrorism.columns=['year','country','nattacks']
df_new.columns=['year','country','nkills']

# %%
df_terrorism = df_terrorism.merge(df_new)

# %%
country_code = pd.read_csv('country_code.csv',encoding='latin-1')
country_code.columns=['country','country_code']
df_terrorism = df_terrorism.merge(country_code,on='country',how='left')

# %%
df_terrorism.drop('country',axis=1,inplace=True)
df_terrorism.head()
# Out:
#    year  nattacks  nkills country_code
# 0  1970        21     5.0          ARG
# 1  1970         1     0.0          AUS
# 2  1970         1     0.0          BEL
# 3  1970         1     0.0          BOL
# 4  1970         6     2.0          BRA

# %%
# Get all combinations of year country possible
from itertools import product

year = np.arange(df_terrorism.year.min(),df_terrorism.year.max()+1)
country = list(df_terrorism.country_code.unique())
df_comb = pd.DataFrame(list(product(year, country)), columns=['year', 'country_code'])
df_comb['data'] = 0
df_terrorism = df_comb.merge(df_terrorism,how='left')
df_terrorism.fillna(0,inplace=True)
df_terrorism.drop('data',axis=1,inplace=True)
df_terrorism.head()
# Out:
#    year country_code  nattacks  nkills
# 0  1970          ARG      21.0     5.0
# 1  1970          AUS       1.0     0.0
# 2  1970          BEL       1.0     0.0
# 3  1970          BOL       1.0     0.0
# 4  1970          BRA       6.0     2.0

# %%
country_code.head()
# Out:
#           country country_code
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND

# %%
df_terrorism[df_terrorism.Country.isna()]['country'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-ded4c702c00b> in <module>()
# ----> 1 df_terrorism[df_terrorism.Country.isna()]['country'].unique()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Country'

# %%
df_terrorism.groupby('iyear').nkill.sum().plot()
plt.show()

# %%
df_terrorism.plot.scatter(x='iyear',y='nkill')

# %% [markdown]
# We will be interested on the most killing attacks, that is attacks with at least 5 kills

# %%
kill_df = df_terrorism[df_terrorism.nkill > 5]

# %%
year_attacks = kill_df.iyear.unique()

# %% [markdown]
# # Political parties

# %%
cpds = pd.read_excel('http://www.cpds-data.org/images/Update2019/CPDS-1960-2017-Update-2019.xlsx', parse_dates=True)

# %%
cpds.head()
# Out:
#    year    country  countryn  iso  ...       pop65   elderly  year_13  country_13
# 0  1960  Australia         1  AUS  ...  871.096008  8.465703     1960   Australia
# 1  1961  Australia         1  AUS  ...  890.710999  8.488172     1961   Australia
# 2  1962  Australia         1  AUS  ...  909.627991  8.507805     1962   Australia
# 3  1963  Australia         1  AUS  ...  928.943970  8.526904     1963   Australia
# 4  1964  Australia         1  AUS  ...  943.978027  8.492668     1964   Australia
#
# [5 rows x 319 columns]

# %%
df_politic = cpds[['year','iso']].copy()
df_politic.columns = ['year','country_code']

# %%
df_politic['elec_leftsoc'] = cpds['leftsoc1']+cpds['leftsoc2']+cpds['leftsoc3']+cpds['leftsoc4']+cpds['leftsoc5']
df_politic['elec_comm'] = cpds['comm1']+cpds['comm2']+cpds['comm3']+cpds['comm4']
df_politic['elec_conserv'] = cpds['conserv1']+cpds['conserv2']+cpds['conserv3']+cpds['conserv4']+cpds['conserv5']+cpds['conserv6']+cpds['conserv7']+cpds['conserv8']
df_politic['elec_right'] = cpds['right1']+cpds['right2']+cpds['right3']+cpds['right4']+cpds['right5']+cpds['right6']

# %%
df_politic['left_soc_inc'] = df_politic.groupby(['country_code']).elec_leftsoc.diff()
df_politic['comm_inc'] = df_politic.groupby(['country_code']).elec_comm.diff()
df_politic['conserv_inc'] = df_politic.groupby(['country_code']).elec_conserv.diff()
df_politic['right_inc'] = df_politic.groupby(['country_code']).elec_right.diff()
df_politic.drop(['elec_leftsoc','elec_comm','elec_conserv','elec_right'],axis=1,inplace=True)
df_politic.head()
# Out:
#    year country_code  left_soc_inc  comm_inc  conserv_inc  right_inc
# 0  1960          AUS           NaN       NaN          NaN        NaN
# 1  1961          AUS           0.0       0.0         -3.6        0.0
# 2  1962          AUS           0.0       0.0          0.0        0.0
# 3  1963          AUS           0.0       0.0          3.5        0.0
# 4  1964          AUS           0.0       0.0          0.0        0.0

# %%
df_politic.left_soc_inc.replace(to_replace=np.float64(0), value=None,inplace=True,method='ffill')
df_politic.comm_inc.replace(to_replace=np.float64(0), value=None,inplace=True,method='ffill')
df_politic.conserv_inc.replace(to_replace=np.float64(0), value=None,inplace=True,method='ffill')
df_politic.right_inc.replace(to_replace=np.float64(0), value=None,inplace=True,method='ffill')
df_politic.head()
# Out:
#    year country_code  left_soc_inc  comm_inc  conserv_inc  right_inc
# 0  1960          AUS           NaN       NaN          NaN        NaN
# 1  1961          AUS           NaN       NaN         -3.6        NaN
# 2  1962          AUS           NaN       NaN         -3.6        NaN
# 3  1963          AUS           NaN       NaN          3.5        NaN
# 4  1964          AUS           NaN       NaN          3.5        NaN

# %% [markdown]
# # Economic openess

# %%
df_openess = cpds[['year','iso','kaopen','openc']].copy()
df_openess.columns = ['year','country_code','kaopen','openc']
df_openess.head()
# Out:
#    year country_code  kaopen     openc
# 0  1960          AUS     NaN  27.37579
# 1  1961          AUS     NaN  26.54761
# 2  1962          AUS     NaN  26.80380
# 3  1963          AUS     NaN  28.67068
# 4  1964          AUS     NaN  28.44636

# %% [markdown]
# # Happiness Index

# %%
happiness2015_df = pd.read_csv('2015.csv')
happiness2015_df.drop(['Region','Standard Error'],axis=1,inplace=True)
happiness2015_df.columns = ['country','happiness_rank','happiness_score','gdp_per_capita','family','life','freedom','generosity','trust','dystopia']
happiness2015_df['year'] = 2015
happiness2015_df.head()
# Out:
#        country  happiness_rank  happiness_score  ...    trust  dystopia  year
# 0  Switzerland               1            7.587  ...  0.29678   2.51738  2015
# 1      Iceland               2            7.561  ...  0.43630   2.70201  2015
# 2      Denmark               3            7.527  ...  0.34139   2.49204  2015
# 3       Norway               4            7.522  ...  0.34699   2.46531  2015
# 4       Canada               5            7.427  ...  0.45811   2.45176  2015
#
# [5 rows x 11 columns]

# %%
happiness2016_df = pd.read_csv('2016.csv')
happiness2016_df.drop(['Region','Lower Confidence Interval','Upper Confidence Interval'],axis=1,inplace=True)
happiness2016_df.columns= ['country','happiness_rank','happiness_score','gdp_per_capita','family','life','freedom','generosity','trust','dystopia']
happiness2016_df['year'] = 2016
happiness2016_df.head()
# Out:
#        country  happiness_rank  happiness_score  ...    trust  dystopia  year
# 0      Denmark               1            7.526  ...  0.36171   2.73939  2016
# 1  Switzerland               2            7.509  ...  0.28083   2.69463  2016
# 2      Iceland               3            7.501  ...  0.47678   2.83137  2016
# 3       Norway               4            7.498  ...  0.37895   2.66465  2016
# 4      Finland               5            7.413  ...  0.25492   2.82596  2016
#
# [5 rows x 11 columns]

# %%
happiness2017_df = pd.read_csv('2017.csv')
happiness2017_df.drop(['Whisker.high','Whisker.low'],axis=1,inplace=True)
happiness2017_df.columns= ['country','happiness_rank','happiness_score','gdp_per_capita','family','life','freedom','generosity','trust','dystopia']
happiness2017_df['year'] = 2017
happiness2017_df.head()
# Out:
#        country  happiness_rank  happiness_score  ...     trust  dystopia  year
# 0       Norway               1            7.537  ...  0.315964  2.277027  2017
# 1      Denmark               2            7.522  ...  0.400770  2.313707  2017
# 2      Iceland               3            7.504  ...  0.153527  2.322715  2017
# 3  Switzerland               4            7.494  ...  0.367007  2.276716  2017
# 4      Finland               5            7.469  ...  0.382612  2.430182  2017
#
# [5 rows x 11 columns]

# %%
happiness_df = happiness2015_df.merge(happiness2016_df,how='outer')
happiness_df = happiness_df.merge(happiness2017_df,how='outer')
happiness_df = happiness_df.merge(country_code,on='country',how='left')
happiness_df.drop(['country','happiness_rank'],axis=1,inplace=True)
happiness_df.head()
# Out:
#    happiness_score  gdp_per_capita   family  ...  dystopia  year  country_code
# 0            7.587         1.39651  1.34951  ...   2.51738  2015           CHE
# 1            7.561         1.30232  1.40223  ...   2.70201  2015           ISL
# 2            7.527         1.32548  1.36058  ...   2.49204  2015           DNK
# 3            7.522         1.45900  1.33095  ...   2.46531  2015           NOR
# 4            7.427         1.32629  1.32261  ...   2.45176  2015           CAN
#
# [5 rows x 10 columns]

# %% [markdown]
# # Merge all datas

# %%
from functools import reduce
dfs = [happiness_df,df_openess,df_terrorism,df_politic,df_tourism]
global_df = reduce(lambda left,right: pd.merge(left,right,on=['year','country_code'],how='outer'), dfs)
global_df.to_csv('global.csv')

# %%
global_df = pd.read_csv('global.csv',index_col=0)

# %%
global_df.head()
# Out:
#    happiness_score  gdp_per_capita   family  ...  right_inc       gde       gdi
# 0            7.587         1.39651  1.34951  ...        2.8 -0.038249 -0.025156
# 1            7.561         1.30232  1.40223  ...        3.0  0.213081  0.153492
# 2            7.527         1.32548  1.36058  ...        8.8  0.028386  0.040878
# 3            7.522         1.45900  1.33095  ...       16.3  0.118585  0.061523
# 4            7.427         1.32629  1.32261  ...        NaN  0.074071  0.017096
#
# [5 rows x 20 columns]

# %%
feature = 'nattacks'
year = 2015
# Take only value of year 2001
df = global_df[global_df.year.isin([year])].copy()[['year','country_code',feature]]
df[feature].fillna(0,inplace=True)
df.head()
# Out:
#    year country_code  nattacks
# 0  2015          CHE       0.0
# 1  2015          ISL       0.0
# 2  2015          DNK       5.0
# 3  2015          NOR       0.0
# 4  2015          CAN       5.0

# %%
import geopandas as gpd
shapefile = 'ne_110m_admin_0_countries.shp'
#Read shapefile using Geopandas
gdf = gpd.read_file(shapefile)[['ADMIN', 'ADM0_A3', 'geometry']]
gdf.drop('ADMIN',axis=1,inplace=True)
#Rename columns.
gdf.columns = ['country_code', 'geometry']
gdf.head()
# Out:
#   country_code                                           geometry
# 0          FJI  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1          TZA  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2          SAH  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3          CAN  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4          USA  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
merged_df = gdf.merge(df, on='country_code',how='left')
# If nan in year, there is no data abound the feature
merged_df[feature].mask(merged_df.year.isna(),'No Data',inplace=True)
# If year is not nan, there is data in the feature and it is 0
#merged_df['nattacks'].replace(np.nan,0,inplace=True)

# %%
merged_df.head()
# Out:
#   country_code  ... nattacks
# 0          FJI  ...        0
# 1          TZA  ...       14
# 2          SAH  ...  No Data
# 3          CAN  ...        5
# 4          USA  ...       38
#
# [5 rows x 4 columns]

# %%
import json
#Read data to json.
merged_json = json.loads(merged_df.to_json())
#Convert to String like object.
json_data = json.dumps(merged_json)

# %%
from bokeh.io import curdoc, output_notebook
from bokeh.models import Slider, HoverTool
from bokeh.layouts import widgetbox, row, column
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar, LogColorMapper
from bokeh.palettes import brewer

#Display figure inline in Jupyter Notebook.
output_notebook()

# %%
#Input GeoJSON source that contains features for plotting.
geosource = GeoJSONDataSource(geojson = json_data)
#Define a sequential multi-hue color palette.
palette = brewer['YlGnBu'][8]
#Reverse color order so that dark blue is highest number of attacks.
palette = palette[::-1]
#Instantiate LogColorMapper that log maps numbers in a range, into a sequence of colors.
color_mapper = LogColorMapper(palette = palette, low = 0, high = 500, nan_color = '#d9d9d9')
#Define custom tick labels for color bar.
tick_labels = {'500':'>500'}
#Create color bar. 
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 850, height = 20,
border_line_color=None,location = (0,0), orientation = 'horizontal', major_label_overrides = tick_labels)
#Create figure object.
p = figure(title = F'{feature} in {year}', plot_height = 600 , plot_width = 950, toolbar_location = None)
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
#Add patch renderer to figure. 
p.patches('xs','ys', source = geosource,fill_color = {'field' :feature, 'transform' : color_mapper},
          line_color = 'black', line_width = 0.25, fill_alpha = 1)
#Specify figure layout.
p.add_layout(color_bar, 'below')

#Display figure.
show(p)
# Out:
#   <div class="bk-root" id="95d99e93-b3df-4995-8e1f-b431e58a0358" data-root-id="1119"></div>

# %% [markdown]
# # Focus on occentidal countries (EU + North America)

# %%
western_world = ['United States','Canada','Spain','Portugal','France','United Kingdom','Ireland','Luxembourg','Belgium','Netherlands','Germany',
                 'Switzerland','Italy','Austria','Norway','Denmark','Iceland','Sweden','Finland','Japan','South Korea','Australia',
                 'New Zealand','Greece']

# %%
countries_df = pd.read_csv('country_code.csv',encoding='latin-1')
countries_df.head()
# Out:
#           Country Alpha3
# 0     Afghanistan    AFG
# 1         Albania    ALB
# 2         Algeria    DZA
# 3  American Samoa    ASM
# 4         Andorra    AND

# %%
western_codes = list(countries_df[countries_df.Country.isin(western_world)].Alpha3)

# %%
western_df = global_df[global_df.country_code.isin(western_codes)].copy()

# %%
df.head()
# Out:
#      happiness_score  gdp_per_capita    family  ...  elec_right       gde       gdi
# 315            7.537        1.616463  1.533524  ...        15.2       NaN       NaN
# 316            7.522        1.482383  1.551122  ...        21.1  0.032407  0.033835
# 317            7.504        1.480633  1.610574  ...         0.0 -0.302182  0.110406
# 318            7.494        1.564980  1.516912  ...        29.4 -0.114001 -0.095816
# 319            7.469        1.443572  1.540247  ...        17.7  0.265711  0.051392
#
# [5 rows x 19 columns]

# %%
import seaborn as sns
# %matplotlib inline

years = [2015,2016,2017]
for y in years:

  df = western_df[western_df.year.isin([y])].copy()
  df.drop('year',axis=1,inplace=True)

  corr = df.corr()
  sns.set(style="white")
  # Set up the matplotlib figure
  f, ax = plt.subplots(figsize=(8, 8))

  # Generate a custom diverging colormap
  cmap = sns.diverging_palette(220, 10, as_cmap=True)

  # Draw the heatmap with the mask and correct aspect ratio
  sns.heatmap(corr, cmap=cmap, vmax=1, vmin=-1, center=0,
              square=True, linewidths=.5, cbar_kws={"shrink": .5})
  
  plt.title(F'correlation matrix in {y}')

  plt.show()

# %% [markdown]
# # OTHERS

# %% [markdown]
# Construct a reduce dataset with 3 countries of interest for now

# %%
cpds_red = cpds[cpds.country.isin(['France','Germany','United Kingdom'])]

# %% [markdown]
# Plot real GDP for these countries from 1960 to 2017

# %%
cpds_red.set_index('year').groupby('country')['realgdpgr'].plot(legend=True)
# Out:
# country
# France            AxesSubplot(0.125,0.125;0.775x0.755)
# Germany           AxesSubplot(0.125,0.125;0.775x0.755)
# United Kingdom    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: realgdpgr, dtype: object

# %% [markdown]
# Plot the polulations for these 3 countries

# %%
cpds_red.set_index('year').groupby('country')['pop'].plot(legend=True)
# Out:
# country
# France            AxesSubplot(0.125,0.125;0.775x0.755)
# Germany           AxesSubplot(0.125,0.125;0.775x0.755)
# United Kingdom    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: pop, dtype: object

# %%
for c in ['France', 'United Kingdom', 'Germany'] :
  df = cpds_red[cpds_red.country.isin([c])]
  df.set_index('year').groupby('country')['gov_right1','gov_cent1','gov_left1'].plot(legend=True,title=c)
plt.show()

# %%
for c in ['France', 'United Kingdom', 'Germany'] :
  df = cpds_red[cpds_red.country.isin([c])]
  df.set_index('year').groupby('country')['gov_right2','gov_cent2','gov_left2'].plot(legend=True,title=c)
plt.show()

# %%
for c in ['France', 'United Kingdom', 'Germany'] :
  df = cpds_red[cpds_red.country.isin([c])]
  df.set_index('year').groupby('country')['gov_right3','gov_cent3','gov_left3'].plot(legend=True,title=c)
plt.show()

# %%
for c in ['France', 'United Kingdom', 'Germany'] :
  df = cpds_red[cpds_red.country.isin([c])]
  print(df.columns[df.columns.str.contains('social' or 'left')])
  #df.set_index('year').groupby('country')['gov_right3','gov_cent3','gov_left3'].plot(legend=True,title=c)
plt.show()
# Out:
# Index(['social1', 'social2', 'social3', 'social4', 'social5', 'social6',
#        'social7', 'social8', 'ssocial1', 'ssocial2', 'ssocial3', 'ssocial4',
#        'ssocial5', 'ssocial6', 'ssocial7', 'ssocial8'],
#       dtype='object')
# Index(['social1', 'social2', 'social3', 'social4', 'social5', 'social6',
#        'social7', 'social8', 'ssocial1', 'ssocial2', 'ssocial3', 'ssocial4',
#        'ssocial5', 'ssocial6', 'ssocial7', 'ssocial8'],
#       dtype='object')
# Index(['social1', 'social2', 'social3', 'social4', 'social5', 'social6',
#        'social7', 'social8', 'ssocial1', 'ssocial2', 'ssocial3', 'ssocial4',
#        'ssocial5', 'ssocial6', 'ssocial7', 'ssocial8'],
#       dtype='object')

# %% [markdown]
# Plot the cabinet composition according to the Schmidt index :
# 1. hegemony of right-wing (and centre) par-ties
# 2. dominance    of    right-wing    (and centre)    parties
# 3. balance    of    powerbetween    left    andright
# 4. dominance of social-democratic and other left parties
# 5. hegemony of social-democratic and other left parties

# %%
cpds_red.set_index('year').groupby('country')['gov_party'].plot(legend=True)
plt.show()

# %% [markdown]
# It should be interesting to work with [vote intentions](https://www.politico.eu/europe-poll-of-polls/france/). The code to retrieve datas from scatter plot is write on an other file. Ask to get it... Here is an example of such a plot

# %%
from IPython.display import Image
Image(filename='germany-poll.png')

# %%
df = cpds[cpds.country.isin(['France'])]

# %% [markdown]
# TODO
#
#
# *   GDP across years
# *   Population
# *   Happyness index
# *   Political elections

# %%
df.head()
# Out:
#      year country  countryn  iso  ...        pop65    elderly  year_13  country_13
# 490  1960  France        12  FRA  ...  5386.888184  11.549932     1960      France
# 491  1961  France        12  FRA  ...  5478.551758  11.621629     1961      France
# 492  1962  France        12  FRA  ...  5616.622070  11.701540     1962      France
# 493  1963  France        12  FRA  ...  5737.923828  11.748411     1963      France
# 494  1964  France        12  FRA  ...  5852.942871  11.858385     1964      France
#
# [5 rows x 319 columns]

# %%
df.set_index('year').vturn.plot()
plt.show()

# %%
df['social'] = df['social1']+df['social2']+df['social3']+df['social4']+df['social5']+df['social6']+df['social7']+df['social8']
df['leftsoc'] = df['leftsoc1']+df['leftsoc2']+df['leftsoc3']+df['leftsoc4']+df['leftsoc5']
df['comm'] = df['comm1']+df['comm2']+df['comm3']+df['comm4']
df['agrarian'] = df['agrarian1']+df['agrarian2']+df['agrarian3']
df['conserv'] = df['conserv1']+df['conserv2']+df['conserv3']+df['conserv4']+df['conserv5']+df['conserv6']+df['conserv7']+df['conserv8']
df['relig'] = df['relig1']+df['relig2']+df['relig3']+df['relig4']+df['relig5']+df['relig6']+df['relig7']
df['liberal'] = df['liberal1']+df['liberal2']+df['liberal3']+df['liberal4']+df['liberal5']+df['liberal6']+df['liberal7']+df['liberal8']+df['liberal9']
df['protest'] = df['protest1']+df['protest2']+df['protest3']+df['protest4']+df['protest5']
df['green'] = df['green1']+df['green2']+df['green3']
df['ethnic'] = df['ethnic1']+df['ethnic2']+df['ethnic3']+df['ethnic4']
df['right'] = df['right1']+df['right2']+df['right3']+df['right4']+df['right5']+df['right6']
df['allia'] = df['allia1']+df['allia2']+df['allia3']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
political_part = ['leftsoc','comm','right','social','conserv']

# %%
df.set_index('year')[political_part].plot()
plt.show()

# %%
df.set_index('year')[political_part].plot()
for y in year_attacks:
  plt.axvline(y,linestyle='--',color='black')
plt.show()

# %%
df.set_index('year')['realgdpgr'].plot()
for y in year_attacks:
  plt.axvline(y,linestyle='--',color='black')
plt.axhline(0,linestyle='--',color='red')
plt.show()

# %%
df.set_index('year')['openc'].plot()
for y in year_attacks:
  plt.axvline(y,linestyle='--',color='black')
plt.axhline(0,linestyle='--',color='red')
plt.show()

# %%
df.set_index('year')['kaopen'].plot()
for y in year_attacks:
  plt.axvline(y,linestyle='--',color='black')
plt.axhline(0,linestyle='--',color='red')
plt.show()

# %%
df.set_index('year')['prefisc_gini'].plot(legend=True)
for y in year_attacks:
  plt.axvline(y,linestyle='--',color='black')
plt.show()

# %%
happiness2015_df = pd.read_csv('2015.csv')
happiness2015_df['Year'] = 2015
happiness2016_df = pd.read_csv('2016.csv')
happiness2016_df['Year'] = 2016
happiness2017_df = pd.read_csv('2017.csv')
happiness2017_df['Year'] = 2017

# %%
happy_df = happiness2015_df.merge(happiness2016_df,how='outer')
happy_df = happy_df.merge(happiness2017_df,how='outer')
happy_df[happy_df.Country.isin(['France'])]
# Out:
#     Country          Region  ...  Trust..Government.Corruption.  Dystopia.Residual
# 28   France  Western Europe  ...                            NaN                NaN
# 189  France  Western Europe  ...                            NaN                NaN
# 345  France             NaN  ...                       0.172502           2.005955
#
# [3 rows x 23 columns]

# %%
happy_df = pd.read_csv('share-of-people-who-say-they-are-happy-Eurobarometer.csv')

# %%
happy_df[happy_df.Entity.isin(['France'])].head()
# Out:
#      Entity Code  Year  Share of people who are happy (Eurobarometer 2017) (%)
# 236  France  FRA  1973                                          77.000000
# 237  France  FRA  1975                                          73.881378
# 238  France  FRA  1976                                          71.098106
# 239  France  FRA  1977                                          70.053268
# 240  France  FRA  1978                                          70.380768

# %%
cantril_df = pd.read_csv('happiness-cantril-ladder.csv',skiprows=1,
                         names=['Country','Code','Year','HI'])
cantril_df.head()
# Out:
#        Country Code  Year        HI
# 0  Afghanistan  AFG  2008  3.723590
# 1  Afghanistan  AFG  2009  4.401778
# 2  Afghanistan  AFG  2010  4.758381
# 3  Afghanistan  AFG  2011  3.831719
# 4  Afghanistan  AFG  2012  3.782938

# %%
cantril_df[cantril_df.Country.isin(['France'])].plot(x='Year',y='HI')
for y in year_attacks:
  plt.axvline(y,linestyle='--',color='black')
plt.show()

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 921kB 9.8MB/s
# ...
#      |████████████████████████████████| 10.1MB 55.3MB/s
# ...
#      |████████████████████████████████| 11.8MB 186kB/s
# ...

# %%
import geopandas as gpd

# %%
country_code = pd.read_csv('https://pkgstore.datahub.io/core/country-codes/country-codes_csv/data/3b9fd39bdadd7edd7f7dcee708f47e1b/country-codes_csv.csv')

# %%
country_code.head()
# Out:
#   official_name_ar official_name_cn official_name_en  ...  TLD  WMO   is_independent
# 0              NaN              NaN              NaN  ...  .tw  NaN              Yes
# 1        أفغانستان              阿富汗      Afghanistan  ...  .af   AF              Yes
# 2          ألبانيا            阿尔巴尼亚          Albania  ...  .al   AB              Yes
# 3          الجزائر            阿尔及利亚          Algeria  ...  .dz   AL              Yes
# 4  ساموا الأمريكية            美属萨摩亚   American Samoa  ...  .as  NaN  Territory of US
#
# [5 rows x 56 columns]

# %%
country_code = country_code[['official_name_en','ISO3166-1-Alpha-2','ISO3166-1-Alpha-3']]
country_code.columns = ['Country','ISO2','ISO3']
country_code[country_code.ISO3.isin(['TZA'])]
# Out:
#                          Country ISO2 ISO3
# 235  United Republic of Tanzania   TZ  TZA

# %%
shapefile = 'ne_110m_admin_0_countries.shp'
#Read shapefile using Geopandas
gdf = gpd.read_file(shapefile)[['ADMIN', 'ADM0_A3', 'geometry']]
#Rename columns.
gdf.columns = ['country', 'country_code', 'geometry']
gdf.head()
# Out:
#                        country  ...                                           geometry
# 0                         Fiji  ...  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  United Republic of Tanzania  ...  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2               Western Sahara  ...  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3                       Canada  ...  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4     United States of America  ...  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#
# [5 rows x 3 columns]

# %%
attack = df_terrorism.groupby(['iyear','country']).count(

# %%
df_terrorism[~df_terrorism.country_txt.isin(gdf.country.unique())].country_txt.unique()
# Out:
# array(['United States', 'East Germany (GDR)', 'West Germany (FRG)',
#        'South Yemen', 'West Bank and Gaza Strip', 'Czechoslovakia',
#        'South Vietnam', 'Zaire', "People's Republic of the Congo",
#        'Yugoslavia', 'Singapore', 'North Yemen', 'Andorra', 'Tanzania',
#        'Bahamas', 'Barbados', 'Malta', 'Rhodesia', 'Soviet Union',
#        'Bahrain', 'Hong Kong', 'Grenada', 'New Hebrides', 'Guadeloupe',
#        'Martinique', 'Vatican City', 'Seychelles', 'Dominica',
#        'Swaziland', 'French Guiana', 'Maldives', 'Mauritius',
#        'Antigua and Barbuda', 'Bosnia-Herzegovina', 'Comoros',
#        'Slovak Republic', 'Wallis and Futuna', 'Czech Republic',
#        'St. Kitts and Nevis', 'French Polynesia', 'Macau', 'St. Lucia',
#        'International', 'Serbia-Montenegro', 'Serbia'], dtype=object)

# %%
df_terrorism = df_terrorism.merge(country_code,left_on='country_txt',right_on='Country')

# %%
attacks = pd.DataFrame(df_terrorism.groupby(['iyear','country_txt']).size())

# %%
attacks.reset_index(inplace=True)
attacks.columns=['year','country','nattacks']
attacks = attacks.merge(country_code,left_on='country',right_on='Country')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-327-ec834cf39574> in <module>()
#       1 attacks.reset_index(inplace=True)
# ----> 2 attacks.columns=['year','country','nattacks']
#       3 attacks = attacks.merge(country_code,left_on='country',right_on='Country')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
# ...

# %%
attacks.nattacks.describe()
# Out:
# count    3241.000000
# mean       53.301759
# std       197.608085
# min         1.000000
# 25%         2.000000
# 50%         5.000000
# 75%        22.000000
# max      3934.000000
# Name: nattacks, dtype: float64

# %%
gdf.head()
# Out:
#                        country  ...                                           geometry
# 0                         Fiji  ...  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  United Republic of Tanzania  ...  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2               Western Sahara  ...  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3                       Canada  ...  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4     United States of America  ...  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#
# [5 rows x 3 columns]

# %%
#Filter data for year 2016.
attacks_2001 = attacks[attacks['year'] == 2001]
#Merge dataframes gdf and df_2016
merged = gdf.merge(attacks_2001, left_on = 'country_code', right_on = 'ISO3',how='left')
#Replace NaN values to string 'No data'.

# %%
merged.head()
# Out:
#                      country_x country_code  ... ISO2  ISO3
# 0                         Fiji          FJI  ...   FJ   FJI
# 1  United Republic of Tanzania          TZA  ...  NaN   NaN
# 2               Western Sahara          SAH  ...  NaN   NaN
# 3                       Canada          CAN  ...  NaN   NaN
# 4     United States of America          USA  ...  NaN   NaN
#
# [5 rows x 9 columns]

# %%
merged[merged.ISO3.isin(['USA'])]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _repr_html_(self)
#     700                 render_links=False,
#     701             )
# --> 702             formatter.to_html(notebook=True)
#     703             return formatter.buf.getvalue()
#     704         else:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/format.py in to_html(self, classes, notebook, border)
#     838
#     839         Klass = NotebookFormatter if notebook else HTMLFormatter
# ...

# %%
import json
#Read data to json.
merged_json = json.loads(merged.to_json())
#Convert to String like object.
json_data = json.dumps(merged_json)

# %%
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.models import GeoJSONDataSource, LogColorMapper, ColorBar
from bokeh.palettes import brewer

#Display figure inline in Jupyter Notebook.
output_notebook()

# %%
#Input GeoJSON source that contains features for plotting.
geosource = GeoJSONDataSource(geojson = json_data)
#Define a sequential multi-hue color palette.
palette = brewer['YlGnBu'][8]
#Reverse color order so that dark blue is highest number of attacks.
palette = palette[::-1]
#Instantiate LogColorMapper that log maps numbers in a range, into a sequence of colors.
color_mapper = LogColorMapper(palette = palette, low = 0, high = 500, nan_color = '#d9d9d9')
#Define custom tick labels for color bar.
tick_labels = {'500':'>500'}
#Create color bar. 
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 850, height = 20,
border_line_color=None,location = (0,0), orientation = 'horizontal', major_label_overrides = tick_labels)
#Create figure object.
p = figure(title = 'Number of terrorist attacks 2001', plot_height = 600 , plot_width = 950, toolbar_location = None)
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
#Add patch renderer to figure. 
p.patches('xs','ys', source = geosource,fill_color = {'field' :'nattacks', 'transform' : color_mapper},
          line_color = 'black', line_width = 0.25, fill_alpha = 1)
#Specify figure layout.
p.add_layout(color_bar, 'below')

#Display figure.
show(p)
# Out:
#   <div class="bk-root" id="62e594c2-87b0-4189-bd0b-4b29ec0f5f37" data-root-id="10492"></div>

# %% [markdown]
# More Interactive Data Visualisation on :
# https://realpython.com/python-data-visualization-bokeh/

# %%
import pandas as pd
rel_df = pd.read_csv('https://query.data.world/s/bsfnpryukgahrsr235xpd5bf33je4i')
rel_df['islmpct'] = rel_df['islmsunpct']+rel_df['islmshipct']+rel_df['islmibdpct']+rel_df['islmnatpct']+rel_df['islmalwpct']\
+rel_df['islmahmpct']+rel_df['islmothrpct']+rel_df['islmgenpct']
rel_df.head()
# Out:
#    year  state name  chrstprot  ...  reliabilevel  Version  sourcecode  islmpct
# 0  1945      2  USA   66069671  ...        Medium      1.1          13      0.0
# 1  1950      2  USA   73090083  ...           Low      1.1          18      0.0
# 2  1955      2  USA   79294628  ...        Medium      1.1          15      0.0
# 3  1960      2  USA   90692928  ...        Medium      1.1          13      0.0
# 4  1965      2  USA   94165803  ...           Low      1.1          20      0.0
#
# [5 rows x 85 columns]

# %% [markdown]
# Problems with country code, non standardized

# %%
islm_rel_df = rel_df[['year','name','chrstgenpct']]
islm_rel_df = islm_rel_df[islm_rel_df.year.isin([2010])]

# %%
islm_rel_df.head()
# Out:
#     year name  chrstgenpct
# 13  2010  USA       0.7454
# 27  2010  CAN       0.7661
# 35  2010  BHM       0.9660
# 49  2010  CUB       0.6589
# 63  2010  HAI       0.8200

# %%
#Merge dataframes gdf and df_2016.
merged = gdf.merge(islm_rel_df, left_on = 'country_code', right_on = 'name',how='left')
merged.head()
# Out:
#                        country country_code  ... name  chrstgenpct
# 0                         Fiji          FJI  ...  NaN          NaN
# 1  United Republic of Tanzania          TZA  ...  NaN          NaN
# 2               Western Sahara          SAH  ...  NaN          NaN
# 3                       Canada          CAN  ...  CAN       0.7661
# 4     United States of America          USA  ...  USA       0.7454
#
# [5 rows x 6 columns]

# %%
import json
#Read data to json.
merged_json = json.loads(merged.to_json())
#Convert to String like object.
json_data = json.dumps(merged_json)

# %%
#Input GeoJSON source that contains features for plotting.
geosource = GeoJSONDataSource(geojson = json_data)
#Define a sequential multi-hue color palette.
palette = brewer['YlGnBu'][8]
#Reverse color order so that dark blue is highest number of attacks.
palette = palette[::-1]
#Instantiate LinearColorMapper that log maps numbers in a range, into a sequence of colors.
color_mapper = LinearColorMapper(palette = palette, low = 0, high = 1)
#Define custom tick labels for color bar.
#Create color bar. 
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 850, height = 20,
border_line_color=None,location = (0,0), orientation = 'horizontal')
#Create figure object.
p = figure(title = 'Percentage of non religion affilitation', plot_height = 600 , plot_width = 950, toolbar_location = None)
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
#Add patch renderer to figure. 
p.patches('xs','ys', source = geosource,fill_color = {'field' :'chrstgenpct', 'transform' : color_mapper},
          line_color = 'black', line_width = 0.25, fill_alpha = 1)
#Specify figure layout.
p.add_layout(color_bar, 'below')

#Display figure.
show(p)
# Out:
#   <div class="bk-root" id="aac8aa7f-857d-409f-8808-8a8aac11644e" data-root-id="9190"></div>
